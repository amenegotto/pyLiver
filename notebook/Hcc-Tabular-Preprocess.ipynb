# %%
import pandas as pd
# %matplotlib inline

# %%
foo = pd.read_csv('../csv/hcc-data-complete-balanced.csv')
foo.head()
foo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 50 columns):
# Gender            204 non-null int64
# Symptoms          204 non-null int64
# Alcohol           204 non-null int64
# HBsAg             204 non-null int64
# HBeAg             204 non-null int64
# HBcAb             204 non-null int64
# HCVAb             204 non-null int64
# Cirrhosis         204 non-null int64
# Endemic           204 non-null int64
# Smoking           204 non-null int64
# Diabetes          204 non-null int64
# Obesity           204 non-null int64
# Hemochro          204 non-null int64
# AHT               204 non-null int64
# CRI               204 non-null int64
# HIV               204 non-null int64
# NASH              204 non-null int64
# Varices           204 non-null int64
# Spleno            204 non-null int64
# PHT               204 non-null int64
# PVT               204 non-null int64
# Metastasis        204 non-null int64
# ...

# %%
foo.hist(figsize=(16,18))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f57645e8b38>,
# ...
#       dtype=object)
