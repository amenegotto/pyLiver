# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

pd.set_option('display.max_column',None)
pd.set_option('display.max_rows',None)
pd.set_option('display.max_seq_items',None)
pd.set_option('display.max_colwidth', 500)
pd.set_option('expand_frame_repr', True)

df_main = pd.read_csv('C:/Users/hp/pyLiver/clinical/clinical_patient_lihc.txt', sep='\t', lineterminator='\r')
df_main
# Out:
#                           bcr_patient_uuid  bcr_patient_barcode  \
# 0                       \nbcr_patient_uuid  bcr_patient_barcode
# 1                                \nCDE_ID:       CDE_ID:2673794
# 2   \n00f209c3-041a-4c6e-8b0f-6383eb3c85fc         TCGA-BC-4073
# 3   \n39baf24a-4032-4c23-b3fe-2c50df1881f6         TCGA-BC-A10W
# 4   \n3dc48ea9-a3c6-437f-af5a-88feb300cc5f         TCGA-BC-A10X
# 5   \n6533648f-1353-4253-b65b-d472aacf5751         TCGA-BC-A10Y
# 6   \n709f1e4d-f5e8-4a0b-8254-23f037f4bae7         TCGA-BC-A10Z
# 7   \ncf028bce-d20d-42b8-8507-1ec94a391e85         TCGA-BC-A110
# 8   \na2c17e87-d8bc-4160-88ae-e3e894d013e4         TCGA-BC-A112
# 9   \n4bbdbe77-f3cb-4b64-9826-72debb734784         TCGA-BC-A216
# 10  \n6dcfc418-ab28-4365-95ea-c1ae254f2341         TCGA-BC-A217
# 11  \n07DD49FC-8A76-41E8-9EB3-107336F68701         TCGA-BC-A3KF
# 12  \n75F43FCA-200A-48B0-BB67-0693D7B91119         TCGA-BC-A3KG
# 13  \n6BB5D506-8FCA-43F3-90A6-03C915D7EDE2         TCGA-BC-A5W4
# ...

# %%
df_drug = pd.read_csv('C:/Users/hp/pyLiver/clinical/clinical_drug_lihc.txt', sep='\t', lineterminator='\r')
df_drug
# Out:
#                           bcr_patient_uuid  bcr_patient_barcode  \
# 0                       \nbcr_patient_uuid  bcr_patient_barcode
# 1                                \nCDE_ID:       CDE_ID:2673794
# 2   \n00f209c3-041a-4c6e-8b0f-6383eb3c85fc         TCGA-BC-4073
# 3   \n00f209c3-041a-4c6e-8b0f-6383eb3c85fc         TCGA-BC-4073
# 4   \n39baf24a-4032-4c23-b3fe-2c50df1881f6         TCGA-BC-A10W
# 5   \n45b566d7-f120-471c-a94a-be7936889f2d         TCGA-DD-A115
# 6   \n0ef95351-0133-4f34-a59c-90934fb161f8         TCGA-DD-A11D
# 7   \n0ef95351-0133-4f34-a59c-90934fb161f8         TCGA-DD-A11D
# 8   \n0ef95351-0133-4f34-a59c-90934fb161f8         TCGA-DD-A11D
# 9   \n520a709a-87f6-4f3d-b2a2-9192e3b65c5b         TCGA-DD-A1EC
# 10  \n6C79F64B-63FE-46F5-BF7B-77208231B0F2         TCGA-DD-A1EG
# 11  \ncab5b264-abab-4bdb-816e-9d2c0ac30629         TCGA-DD-A1EH
# 12  \ncab5b264-abab-4bdb-816e-9d2c0ac30629         TCGA-DD-A1EH
# 13  \ncab5b264-abab-4bdb-816e-9d2c0ac30629         TCGA-DD-A1EH
# ...

# %%
df_followup = pd.read_csv('C:/Users/hp/pyLiver/clinical/clinical_follow_up_v4.0_lihc.txt', sep='\t', lineterminator='\r')
df_followup
# Out:
#                           bcr_patient_uuid  bcr_patient_barcode  \
# 0                       \nbcr_patient_uuid  bcr_patient_barcode
# 1                                \nCDE_ID:       CDE_ID:2673794
# 2   \n00f209c3-041a-4c6e-8b0f-6383eb3c85fc         TCGA-BC-4073
# 3   \n00f209c3-041a-4c6e-8b0f-6383eb3c85fc         TCGA-BC-4073
# 4   \n39baf24a-4032-4c23-b3fe-2c50df1881f6         TCGA-BC-A10W
# 5   \n3dc48ea9-a3c6-437f-af5a-88feb300cc5f         TCGA-BC-A10X
# 6   \n6533648f-1353-4253-b65b-d472aacf5751         TCGA-BC-A10Y
# 7   \n6533648f-1353-4253-b65b-d472aacf5751         TCGA-BC-A10Y
# 8   \n709f1e4d-f5e8-4a0b-8254-23f037f4bae7         TCGA-BC-A10Z
# 9   \ncf028bce-d20d-42b8-8507-1ec94a391e85         TCGA-BC-A110
# 10  \na2c17e87-d8bc-4160-88ae-e3e894d013e4         TCGA-BC-A112
# 11  \n4bbdbe77-f3cb-4b64-9826-72debb734784         TCGA-BC-A216
# 12  \n6dcfc418-ab28-4365-95ea-c1ae254f2341         TCGA-BC-A217
# 13  \n6dcfc418-ab28-4365-95ea-c1ae254f2341         TCGA-BC-A217
# ...

# %%
df_followup_nte = pd.read_csv('C:/Users/hp/pyLiver/clinical/clinical_follow_up_v4.0_nte_lihc.txt', sep='\t', lineterminator='\r')
df_followup_nte
# Out:
#                           bcr_patient_uuid  bcr_patient_barcode  \
# 0                       \nbcr_patient_uuid  bcr_patient_barcode
# 1                                \nCDE_ID:       CDE_ID:2673794
# 2   \n39baf24a-4032-4c23-b3fe-2c50df1881f6         TCGA-BC-A10W
# 3   \n3dc48ea9-a3c6-437f-af5a-88feb300cc5f         TCGA-BC-A10X
# 4   \n6533648f-1353-4253-b65b-d472aacf5751         TCGA-BC-A10Y
# 5   \n709f1e4d-f5e8-4a0b-8254-23f037f4bae7         TCGA-BC-A10Z
# 6   \ncf028bce-d20d-42b8-8507-1ec94a391e85         TCGA-BC-A110
# 7   \na2c17e87-d8bc-4160-88ae-e3e894d013e4         TCGA-BC-A112
# 8   \n75F43FCA-200A-48B0-BB67-0693D7B91119         TCGA-BC-A3KG
# 9   \n75F43FCA-200A-48B0-BB67-0693D7B91119         TCGA-BC-A3KG
# 10  \n75F43FCA-200A-48B0-BB67-0693D7B91119         TCGA-BC-A3KG
# 11  \n6BB5D506-8FCA-43F3-90A6-03C915D7EDE2         TCGA-BC-A5W4
# 12  \naeb17d2b-fa8c-4989-bf3a-d2c74b785455         TCGA-DD-A113
# 13  \n45b566d7-f120-471c-a94a-be7936889f2d         TCGA-DD-A115
# ...

# %%
df_nte = pd.read_csv('C:/Users/hp/pyLiver/clinical/clinical_nte_lihc.txt', sep='\t', lineterminator='\r')
df_nte
# Out:
#                           bcr_patient_uuid  bcr_patient_barcode  \
# 0                       \nbcr_patient_uuid  bcr_patient_barcode
# 1                                \nCDE_ID:       CDE_ID:2673794
# 2   \n6C79F64B-63FE-46F5-BF7B-77208231B0F2         TCGA-DD-A1EG
# 3   \nA5E4412B-0E49-4D86-9CCE-71F440A84048         TCGA-DD-A1EK
# 4   \nA5E4412B-0E49-4D86-9CCE-71F440A84048         TCGA-DD-A1EK
# 5   \n614C0ECF-6A84-4C86-8706-79BE5BB00991         TCGA-DD-A3A7
# 6   \nC0BF9278-9CBB-4361-B4D8-AB172B67E276         TCGA-DD-A4ND
# 7   \nBCE25281-502E-4599-9679-32DC8462FFB1         TCGA-DD-A4NE
# 8   \nBCE25281-502E-4599-9679-32DC8462FFB1         TCGA-DD-A4NE
# 9   \n89791F8F-DC06-4A04-B166-AFBFD6CF53DE         TCGA-DD-A4NG
# 10  \n4012EA90-5768-4ACC-AF3A-BA954F493DB4         TCGA-DD-A4NH
# 11  \n5B8D04B2-EF40-4216-A3BB-42520EFBE863         TCGA-DD-A4NK
# 12  \nB96B7620-5506-4DEF-AFF2-5E888EAF3EA5         TCGA-DD-A4NN
# 13  \n75F78C38-6854-4390-AD11-789B4E549D63         TCGA-DD-A4NO
# ...

# %%
df_omf = pd.read_csv('C:/Users/hp/pyLiver/clinical/clinical_omf_v4.0_lihc.txt', sep='\t', lineterminator='\r')
df_omf
# Out:
#                           bcr_patient_uuid  bcr_patient_barcode  \
# 0                       \nbcr_patient_uuid  bcr_patient_barcode
# 1                                \nCDE_ID:       CDE_ID:2673794
# 2   \ncf028bce-d20d-42b8-8507-1ec94a391e85         TCGA-BC-A110
# 3   \na2c17e87-d8bc-4160-88ae-e3e894d013e4         TCGA-BC-A112
# 4   \n6BB5D506-8FCA-43F3-90A6-03C915D7EDE2         TCGA-BC-A5W4
# 5   \n69D6881B-9E9A-407B-8B02-BAD5FC2455BF         TCGA-DD-A3A8
# 6   \n69D6881B-9E9A-407B-8B02-BAD5FC2455BF         TCGA-DD-A3A8
# 7   \nC0BF9278-9CBB-4361-B4D8-AB172B67E276         TCGA-DD-A4ND
# 8   \nC0BF9278-9CBB-4361-B4D8-AB172B67E276         TCGA-DD-A4ND
# 9   \n518AA9CC-71CF-4734-9D55-B435DA99D300         TCGA-DD-A4NI
# 10                                      \n                  NaN
#
#         bcr_omf_barcode                          bcr_omf_uuid  \
# 0       bcr_omf_barcode                          bcr_omf_uuid
# 1               CDE_ID:                               CDE_ID:
# ...

# %%
df_radiation = pd.read_csv('C:/Users/hp/pyLiver/clinical/clinical_radiation_lihc.txt', sep='\t', lineterminator='\r')
df_radiation
# Out:
#                          bcr_patient_uuid  bcr_patient_barcode  \
# 0                      \nbcr_patient_uuid  bcr_patient_barcode
# 1                               \nCDE_ID:       CDE_ID:2673794
# 2  \n994347ba-3045-4ade-926f-06420fbd906c         TCGA-DD-A116
# 3  \nDD056692-4E2A-4E45-A4D0-357AF9754F0E         TCGA-DD-A39V
# 4  \n1043BC90-72C9-48C9-AE24-F617D0485E78         TCGA-DD-A4NF
# 5  \nA6A3F07C-CED4-451B-B2E5-C93E4ED622C1         TCGA-DD-A4NS
# 6                                      \n                  NaN
#
#    bcr_radiation_barcode                    bcr_radiation_uuid  \
# 0  bcr_radiation_barcode                    bcr_radiation_uuid
# 1                CDE_ID:                               CDE_ID:
# 2    TCGA-DD-A116-R43737  4D4874E2-723B-4C89-9D42-AFEB0D026AAC
# 3    TCGA-DD-A39V-R42708  8AFB1417-AA43-4832-A030-84FDCF7A6348
# 4    TCGA-DD-A4NF-R59457  6C4CEA2F-8A49-4F13-9D5E-D9FA162BC397
# 5    TCGA-DD-A4NS-R43382  9568B44D-1A87-42DB-9AE1-6A57D0A1756B
# ...
