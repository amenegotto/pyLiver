# %%
import pandas as pd
# %matplotlib inline
import random
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/home/amenegotto/Downloads/foo.csv')

# %%
sns.clustermap(df)

# %%
df.head()
# Out:
#    Ressonância Magnética  Tomografia  Histopatologia  Radiomics  \
# 0                      0           0               1          0
# 1                      0           1               0          0
# 2                      1           1               0          0
# 3                      0           0               0          0
# 4                      1           0               0          0
#
#    Atributos Clínicos  Atributos Genéticos  Outros
# 0                   0                    0       0
# 1                   0                    0       0
# 2                   0                    0       0
# 3                   1                    1       1
# 4                   0                    0       0

# %%
sns.lmplot(df, data=df, fit_reg=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-579127902efa> in <module>
# ----> 1 sns.lmplot(df, data=df, fit_reg=False)
#
# TypeError: lmplot() missing 1 required positional argument: 'y'

# %%
sns.heatmap(df, annot=True)

# %%
ax = sns.heatmap(df.corr(), annot=True)

# %%
fig = ax.get_figure()
fig.savefig('/tmp/graph.eps', format='eps', bbox_inches='tight')
